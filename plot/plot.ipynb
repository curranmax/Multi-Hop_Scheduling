# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../')
from runner import readDataFromFile, Input, Output

# %%
filename = '../data/6-20/first_run.txt'
data = readDataFromFile(filename)

# %%
for exper in data:
    inpt, output_by_method = exper
    print '********\n'
    print inpt, '\n'
    for method in output_by_method:
        print method, output_by_method[method], '\n' 
    print '********\n'
# Out:
# ********
#
# num_nodes --> 50, max_route_length --> 3, window_size --> 100, reconfig_delta --> 20, num_routes --> 10, input_source --> sigmetrics, methods --> octopus-r,octopus-s,upper-bound,split,eclipse,octopus+
#
# eclipse total_objective_value --> 915.333333333, packets_delivered --> 884, packets_not_delivered --> 3605, time_slots_used --> 960, time_slots_not_used --> 4040
#
# octopus-s total_objective_value --> 2486.5, packets_delivered --> 2476, packets_not_delivered --> 2013, time_slots_used --> 2497, time_slots_not_used --> 2503
#
# octopus-r total_objective_value --> 1678.66666667, packets_delivered --> 1265, packets_not_delivered --> 3224, time_slots_used --> 2367, time_slots_not_used --> 2616
#
# octopus+ total_objective_value --> 2642.66666667, packets_delivered --> 2464, packets_not_delivered --> 2025, time_slots_used --> 2874, time_slots_not_used --> 2126, packets_by_tag --> 2-hop=7,1-hop=2457
#
# ...

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.min(a)
# Out:
# 1

# %%
np.min(np.min(a, 0)[1:])
# Out:
# 2
